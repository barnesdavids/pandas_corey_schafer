# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Section 1 - Importing data

# %%
df = pd.read_csv('so_2019.csv') ## this file display the responses per questions per respondent
#df_questions = pd.read_csv('schema_questions.csv') ## this file contains questions asked in survey
##pd.set_option("display.max_columns", 85) ## this setting is to display max rows

# %% [markdown]
# ### Inspecting Data

# %%
## check total rows and colums loaded
df.shape
# Out:
# (88883, 85)

# %%
## total memory usage for loading initial data
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option("display.max_rows" , None)

# %%
df.isnull().sum()
# Out:
# Respondent                    0
# MainBranch                  552
# Hobbyist                      0
# OpenSourcer                   0
# OpenSource                 2041
# Employment                 1702
# Country                     132
# Student                    1869
# EdLevel                    2493
# UndergradMajor            13269
# EduOther                   4623
# OrgSize                   17092
# DevType                    7548
# YearsCode                   945
# Age1stCode                 1249
# YearsCodePro              14552
# CareerSat                 16036
# JobSat                    17895
# MgrIdiot                  27724
# MgrMoney                  27726
# MgrWant                   27651
# JobSeek                    8328
# LastHireDate               9029
# LastInt                   21728
# FizzBuzz                  17539
# JobFactors                 9512
# ResumeUpdate              11006
# CurrencySymbol            17491
# CurrencyDesc              17491
# ...

# %%
# %%timeit ## time taken to load data
df
# Out:
# 9.11 ns ± 0.0301 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
## based on .shape() info - we want to display all columns
pd.set_option("display.max_columns", None) ## this setting is to display max columns

# %%
df.head()
# Out:
#    Respondent  \
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#
#                                                                       MainBranch  \
# 0                                         I am a student who is learning to code
# 1                                         I am a student who is learning to code
# 2  I am not primarily a developer, but I write code sometimes as part of my work
# 3                                                 I am a developer by profession
# 4                                                 I am a developer by profession
#
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
#
#                                                                         OpenSource  \
# ...

# %% [markdown]
# ### Section 2 - Selecting Rows and Columns
#
# **iloc**  integer or indexed location - accept numeric values only <br/>
# **loc** label based index - accepts labeled (named) string values only <br/>
# **slicing** <br/>

# %% [markdown]
# ### Section 3 - Indexing

# %%
## pandas creates default index column - numbered
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
## creating new index
df2 = df.set_index('Age')
df2.head(1)
# Out:
#       Respondent                              MainBranch Hobbyist OpenSourcer  \
# Age
# 14.0           1  I am a student who is learning to code      Yes       Never
#
#                                              OpenSource  \
# Age
# 14.0  The quality of OSS and closed source software ...
#
#                                   Employment         Country Student  \
# Age
# 14.0  Not employed, and not looking for work  United Kingdom      No
#
#                         EdLevel UndergradMajor  \
# Age
# 14.0  Primary/elementary school            NaN
#
#                                                EduOther OrgSize DevType  \
# Age
# 14.0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#      YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# Age
# 14.0         4         10          NaN       NaN    NaN      NaN      NaN
#
#      MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# Age
# ...

# %%
df2.index
# Out:
# Float64Index([14.0, 19.0, 28.0, 22.0, 30.0, 28.0, 42.0, 24.0, 23.0,  nan,
#               ...
#                nan,  nan,  nan, 40.0,  nan,  nan,  nan,  nan,  nan, 18.0],
#              dtype='float64', name='Age', length=88883)

# %%
df2.loc[19.0]
# Out:
#       Respondent                              MainBranch Hobbyist  \
# Age
# 19.0           2  I am a student who is learning to code       No
# 19.0          62          I am a developer by profession      Yes
# 19.0         112          I am a developer by profession      Yes
# 19.0         284  I am a student who is learning to code      Yes
# 19.0         346  I am a student who is learning to code      Yes
# ...          ...                                     ...      ...
# 19.0       11613                                     NaN      Yes
# 19.0       36798                                     NaN      Yes
# 19.0       68027                                     NaN      Yes
# 19.0       71160                                     NaN      Yes
# 19.0       86806                                     NaN      Yes
#
#                                             OpenSourcer  \
# Age
# 19.0                            Less than once per year
# ...

# %%
df2.reset_index()
df2.head(1)
# Out:
#       Respondent                              MainBranch Hobbyist OpenSourcer  \
# Age
# 14.0           1  I am a student who is learning to code      Yes       Never
#
#                                              OpenSource  \
# Age
# 14.0  The quality of OSS and closed source software ...
#
#                                   Employment         Country Student  \
# Age
# 14.0  Not employed, and not looking for work  United Kingdom      No
#
#                         EdLevel UndergradMajor  \
# Age
# 14.0  Primary/elementary school            NaN
#
#                                                EduOther OrgSize DevType  \
# Age
# 14.0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#      YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# Age
# 14.0         4         10          NaN       NaN    NaN      NaN      NaN
#
#      MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# Age
# ...

# %%
## indexing when doing initial import of data

reset_index = pd.read_csv('so_2019.csv', index_col='Respondent')
reset_index.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
## can sort index
reset_index.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 88883                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88879                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 5                              I am a developer by profession      Yes
# 4                              I am a developer by profession       No
# 3           I am not primarily a developer, but I write co...      Yes
# 2                      I am a student who is learning to code       No
# 1                      I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 88883       Once a month or more often
# ...

# %%
df_questions = pd.read_csv('schema_questions.csv', index_col='Column')
df_questions.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
df_questions.sort_index(ascending=False, inplace=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
df_questions
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %% [markdown]
# ### Section 4 - Conditional Filtering: rows and colums

# %%
df3 = df[['Respondent','LanguageWorkedWith']]#.dropna()
#pd.set_option('max_colwidth', 300)
print(df3.shape)
# Out:
# (88883, 2)

# %%
df3.isnull().sum()
# Out:
# Respondent               0
# LanguageWorkedWith    1314
# dtype: int64

# %%
df3[df3['LanguageWorkedWith'].isnull()]
print(df3.shape)
# Out:
# (88883, 2)

# %%
df3[df3.isnull().any(axis=1)]
print(df3.shape)
# Out:
# (88883, 2)
